# %% [markdown]
# #  活性化関数

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## ステップ関数

# %%
def step(x):
    return np.array(x>0).astype(np.int)
    
x = np.arange(-5,5,0.1)
y = step(x) 
plt.plot(x,y)
plt.xlabel("x")
plt.ylabel("y")
plt.ylim([-0.1,1.1])
plt.show()

# %% [markdown]
# ## シグモイド関数

# %%
def sigmoid(x):
    return 1 / (1+ np.exp(-x))

x = np.arange(-5,5,0.1)
y = sigmoid(x) 
plt.plot(x,y)
plt.xlabel("x")
plt.ylabel("y")
plt.ylim([-0.1,1.1])
plt.show()

# %% [markdown]
# ## tanh関数

# %%
def tanh(x):
    return np.tanh(x)

x = np.arange(-5,5,0.1)
y = tanh(x) 
plt.plot(x,y)
plt.xlabel("x")
plt.ylabel("y")
plt.ylim([-2,2])
plt.show()

# %% [markdown]
# ### [演習]
# - 以下のReLU関数を完成させましょう

# %% [markdown]
# ## ReLU関数
# - $\mathrm{ReLU(x)} = \max{(x, 0)}$
# - $x$が0以上ならそのまま，0未満なら0と出力する

# %%
def relu(x):
    """
    この関数を編集する
    """
    return x * np.array(x>0).astype(np.int)

x = np.arange(-5,5,0.1)
y = relu(x) 
plt.plot(x,y)
plt.xlabel("x")
plt.ylabel("y")
plt.ylim([-5.0,5])
plt.show()
